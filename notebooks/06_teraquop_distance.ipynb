# %% [markdown]
# # Determining what code distance we should use for benchmark evaluations
#
# We want to pick the distance that corresponds to a $p_L=10^{-12}$ error rate
# logical qubit at physical error rate $p=10^{-3}$.

# %%
import os
import stim
import sinter
import matplotlib.pyplot as plt
import numpy as np

# %%
noise = 1e-3

# Adapted from `getting_started.ipynb` notebook at https://github.com/quantumlib/Stim/blob/main/doc/getting_started.ipynb
surface_code_tasks = [
    sinter.Task(
        circuit = stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            rounds=d * 3,
            distance=d,
            after_clifford_depolarization=noise,
            after_reset_flip_probability=noise,
            before_measure_flip_probability=noise,
            before_round_data_depolarization=noise,
        ),
        json_metadata={'d': d, 'r': d * 3, 'p': noise},
    )
    for d in [3, 5, 7, 9]
]

collected_surface_code_stats: list[sinter.TaskStats] = sinter.collect(
    num_workers=os.cpu_count(),
    tasks=surface_code_tasks,
    decoders=['pymatching'],
    max_shots=5_000_000,
    max_errors=100,
    print_progress=True,
)
# Out:
# Starting 10 workers...
# 4 tasks left:
#   workers    decoder   eta shots_left errors_left json_metadata
#         3 pymatching     ?    5000000         100 d=3,r=9,p=0.001
#         3 pymatching     ?    5000000         100 d=5,r=15,p=0.001
#         2 pymatching 2504m    4999999         100 d=7,r=21,p=0.001
#         2 pymatching     ?    5000000         100 d=9,r=27,p=0.001
# 4 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         3 pymatching   ?    5000000         100 d=3,r=9,p=0.001
#         3 pymatching   ?    5000000         100 d=5,r=15,p=0.001
#         2 pymatching  2m    4996791         100 d=7,r=21,p=0.001
#         2 pymatching   ?    5000000         100 d=9,r=27,p=0.001
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         3 pymatching <1m    4993582          91 d=5,r=15,p=0.001
#         3 pymatching <1m    4988326         100 d=7,r=21,p=0.001
#         4 pymatching <1m    4998703         100 d=9,r=27,p=0.001
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         3 pymatching <1m    4908045          61 d=5,r=15,p=0.001
#         3 pymatching <1m    4970645          99 d=7,r=21,p=0.001
#         4 pymatching <1m    4982524         100 d=9,r=27,p=0.001
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         3 pymatching <1m    4852749          33 d=5,r=15,p=0.001
#         3 pymatching <1m    4930709          98 d=7,r=21,p=0.001
#         4 pymatching <1m    4955900         100 d=9,r=27,p=0.001
# 3 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         3 pymatching <1m    4790285          13 d=5,r=15,p=0.001
#         3 pymatching <1m    4881557          93 d=7,r=21,p=0.001
#         4 pymatching <1m    4929276          99 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    4844147          92 d=7,r=21,p=0.001
#         5 pymatching <1m    4902652          99 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    4794995          88 d=7,r=21,p=0.001
#         5 pymatching <1m    4871659          99 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    4729459          84 d=7,r=21,p=0.001
#         5 pymatching <1m    4833771          98 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    4684403          80 d=7,r=21,p=0.001
#         5 pymatching <1m    4815339          98 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    4629107          76 d=7,r=21,p=0.001
#         5 pymatching <1m    4777451          97 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    4556403          69 d=7,r=21,p=0.001
#         5 pymatching <1m    4764139          97 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    4516467          69 d=7,r=21,p=0.001
#         5 pymatching <1m    4733419          97 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    4428403          61 d=7,r=21,p=0.001
#         5 pymatching <1m    4675051          97 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    4428403          61 d=7,r=21,p=0.001
#         5 pymatching <1m    4661739          97 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    4376179          57 d=7,r=21,p=0.001
#         5 pymatching <1m    4661739          97 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    4256371          54 d=7,r=21,p=0.001
#         5 pymatching <1m    4636139          97 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    4203123          53 d=7,r=21,p=0.001
#         5 pymatching <1m    4530667          96 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    4160115          52 d=7,r=21,p=0.001
#         5 pymatching <1m    4530667          96 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    4057715          46 d=7,r=21,p=0.001
#         5 pymatching <1m    4507115          96 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    3992179          44 d=7,r=21,p=0.001
#         5 pymatching <1m    4476395          96 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    3927667          38 d=7,r=21,p=0.001
#         5 pymatching <1m    4381163          96 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    3853939          34 d=7,r=21,p=0.001
#         5 pymatching <1m    4381163          96 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    3782259          30 d=7,r=21,p=0.001
#         5 pymatching <1m    4343275          96 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    3680883          20 d=7,r=21,p=0.001
#         5 pymatching <1m    4343275          96 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    3575411          12 d=7,r=21,p=0.001
#         5 pymatching <1m    4343275          96 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    3477107           3 d=7,r=21,p=0.001
#         5 pymatching <1m    4236779          96 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#         5 pymatching <1m    3477107           3 d=7,r=21,p=0.001
#         5 pymatching <1m    4123115          94 d=9,r=27,p=0.001
# 2 tasks left:
#   workers    decoder        eta shots_left errors_left json_metadata
#         5 pymatching [draining]    3375731         -12 d=7,r=21,p=0.001
#         5 pymatching        <1m    4123115          94 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    4063382          94 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    4033686          94 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    4009110          94 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    3981462          94 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    3943574          94 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    3934358          94 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    3892374          94 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    3737750          93 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    3543190          90 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    3522710          90 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    3385494          90 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    3359894          90 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    3258518          90 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    3222678          90 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    3082390          88 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    2988182          87 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    2794646          87 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    2705558          87 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    2612374          87 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    2565270          86 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    2379926          86 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    2309270          86 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    2029718          83 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    1894550          80 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    1752214          78 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    1470614          77 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    1333398          76 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m    1229974          76 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m     845974          73 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m     782846          73 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m     455166          71 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m     438656          71 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m     394790          71 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m     100214          71 d=9,r=27,p=0.001
# 1 tasks left:
#   workers    decoder eta shots_left errors_left json_metadata
#        10 pymatching <1m       2451          70 d=9,r=27,p=0.001
# 0 tasks left:

# %%
import scipy.stats

# Compute the line fit.
xs = []
ys = []
log_ys = []
for stats in collected_surface_code_stats:
    d = stats.json_metadata['d']
    if not stats.errors:
        print(f"Didn't see any errors for d={d}")
        continue
    per_shot = stats.errors / stats.shots
    per_round = sinter.shot_error_rate_to_piece_error_rate(per_shot, pieces=stats.json_metadata['r'])
    xs.append(d)
    ys.append(per_round)
    log_ys.append(np.log(per_round))
fit = scipy.stats.linregress(xs, log_ys)
print(fit)
# Out:
# LinregressResult(slope=-1.1745232426566228, intercept=-4.6234909953586385, rvalue=-0.9989790182318933, pvalue=0.0010209817681067213, stderr=0.03755807822604788, intercept_stderr=0.24048904100060609)

# %%
fig, ax = plt.subplots(1, 1)
ax.scatter(xs, ys, label=f"sampled logical error rate at p={noise}")
ax.plot([0, 35],
        [np.exp(fit.intercept), np.exp(fit.intercept + fit.slope * 35)],
        linestyle='--',
        label='least squares line fit')
ax.set_ylim(1e-15, 1e-0)
ax.set_xlim(0, 35)
ax.semilogy()
ax.set_yticks([1e-9, 1e-12, 1e-15, 1e-18])
ax.set_xticks(list(range(13, 35, 2)))
ax.set_title("Projecting distance needed to survive a trillion rounds")
ax.set_xlabel("Code Distance")
ax.set_ylabel("Logical Error Rate per Round")
ax.grid(which='major')
ax.grid(which='minor')
ax.legend()
fig.set_dpi(120)  # Show it bigger

# %% [markdown]
# gigaquop => 15
#
# teraquop => 21
#
# petaquop => 27

# %% [markdown]
# # What if a better decoder makes LER 4x lower?

# %%
fig, ax = plt.subplots(1, 1)
ax.scatter(xs, ys, label=f"sampled logical error rate at p={noise}")
ax.plot([0, 35],
        [1/4*np.exp(fit.intercept), 1/4*np.exp(fit.intercept + fit.slope * 35)],
        linestyle='--',
        label='least squares line fit')
ax.set_ylim(1e-15, 1e-0)
ax.set_xlim(0, 35)
ax.semilogy()
ax.set_yticks([1e-9, 1e-12, 1e-15, 1e-18])
ax.set_xticks(list(range(11, 35, 2)))
ax.set_title("Projecting distance needed to survive a trillion rounds")
ax.set_xlabel("Code Distance")
ax.set_ylabel("Logical Error Rate per Round")
ax.grid(which='major')
ax.grid(which='minor')
ax.legend()
fig.set_dpi(120)  # Show it bigger

# %% [markdown]
# gigaquop => 13
#
# teraquop => 19
#
# petaquop => 25
#
# Reduces distance by 2 for equivalent logical error rate.
